# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler

# %%
df = pd.read_csv('ML_data_2023-03-07.csv')

# %%
df
# Out:
#       Rok produkcji  Przebieg  Pojemność skokowa    Moc  Spalanie W Mieście  \
# 0              2015    112000             1395.0  125.0            6.000000
# 1              1997    230000             1781.0   75.0           11.000000
# 2              2007    126296             1390.0  140.0            9.000000
# 3              2007    367800             1896.0  105.0            6.000000
# 4              2008    293000             1896.0  105.0            8.000000
# ...             ...       ...                ...    ...                 ...
# 1458           1988    142961             1781.0  107.0            6.164663
# 1459           2015     52109             1395.0  125.0            6.000000
# 1460           2019     58000             1498.0  150.0            6.100000
# 1461           2005    195670             1595.0  102.0            9.000000
# 1462           2010    189000             1598.0  105.0            5.200000
#
# ...

# %%
corr = df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr = df[['Cena', 'Rok produkcji', 'Przebieg', 'Moc', 'Spalanie W Mieście']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df_lr = df.copy()
scaler = MaxAbsScaler()
scaler.fit(df_lr)
df_lr=pd.DataFrame(scaler.transform(df_lr))
df_lr.columns = df.columns
df_lr
# Out:
#       Rok produkcji  Przebieg  Pojemność skokowa       Moc  \
# 0          0.996045  0.257471           0.437441  0.393082
# 1          0.987148  0.528736           0.558482  0.235849
# 2          0.992091  0.290336           0.435873  0.440252
# 3          0.992091  0.845517           0.594544  0.330189
# 4          0.992585  0.673563           0.594544  0.330189
# ...             ...       ...                ...       ...
# 1458       0.982699  0.328646           0.558482  0.336478
# 1459       0.996045  0.119791           0.437441  0.393082
# 1460       0.998023  0.133333           0.469740  0.471698
# 1461       0.991102  0.449816           0.500157  0.320755
# 1462       0.993574  0.434483           0.501098  0.330189
#
#       Spalanie W Mieście      Cena  Oferta od_Firmy  \
# 0               0.375000  0.274239              0.0
# 1               0.687500  0.017018              0.0
# 2               0.562500  0.096762              0.0
# ...

# %%
sns.regplot(y='Cena', x ='Moc', data=df)
# Out:
# <AxesSubplot:xlabel='Moc', ylabel='Cena'>

# %%
sns.histplot(df.Przebieg)
# Out:
# <AxesSubplot:xlabel='Przebieg', ylabel='Count'>

# %%
df[df['Moc'] == df['Moc'].max()]
# Out:
#       Rok produkcji  Przebieg  Pojemność skokowa    Moc  Spalanie W Mieście  \
# 1300           1999     35470             1781.0  318.0                11.0
#
#        Cena  Oferta od_Firmy  Oferta od_Osoby prywatnej  \
# 1300  29999                1                          0
#
#       Rodzaj paliwa_Benzyna  Rodzaj paliwa_Diesel  \
# 1300                      1                     0
#
#       Skrzynia biegów_Automatyczna  Skrzynia biegów_Manualna  \
# 1300                             0                         1
#
#       Kraj pochodzenia_Inne  Kraj pochodzenia_Niemcy  Kraj pochodzenia_Polska  \
# 1300                      1                        0                        0
#
#       Zarejestrowany w Polsce_Nie  Zarejestrowany w Polsce_Tak
# 1300                            0                            1
