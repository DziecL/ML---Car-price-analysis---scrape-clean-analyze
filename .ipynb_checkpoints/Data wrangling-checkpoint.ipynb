# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# Initial data cleaning and preliminary data exploration

# %%
df = pd.read_csv('otomoto_scraping_2023-02-21.csv')

# %%
df.head()
# Out:
#                                                 link        Oferta od  \
# 0  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 1  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 2  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 3  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 4  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
#
#   Kategoria        Generacja  Rok produkcji    Przebieg Pojemność skokowa  \
# 0   Osobowe  VII (2012-2020)           2015  112 000 km         1 395 cm3
# 1   Osobowe  III (1991-1998)           1997  230 000 km         1 781 cm3
# 2   Osobowe    V (2003-2009)           2008  269 000 km         1 390 cm3
# 3   Osobowe     VIII (2020-)           2022         NaN         1 984 cm3
# 4   Osobowe     VIII (2020-)           2022         NaN         1 984 cm3
#
#   Rodzaj paliwa     Moc Skrzynia biegów  ... Spalanie W Mieście Typ nadwozia  \
# 0       Benzyna  125 KM        Manualna  ...          6 l/100km      Kompakt
# 1       Benzyna   75 KM        Manualna  ...         11 l/100km      Kompakt
# 2       Benzyna  122 KM        Manualna  ...                NaN        Kombi
# 3       Benzyna     NaN    Automatyczna  ...                NaN      Kompakt
# 4       Benzyna     NaN    Automatyczna  ...                NaN      Kompakt
#
#   Liczba drzwi  Liczba miejsc   Kolor Kraj pochodzenia  \
# 0          5.0            5.0   Szary           Polska
# 1          2.0            5.0  Czarny              NaN
# 2          5.0            5.0   Szary         Holandia
# 3          NaN            NaN   Biały           Polska
# 4          NaN            NaN  Czarny           Polska
#
#   Zarejestrowany w Polsce Bezwypadkowy     Stan     Cena
# 0                     Tak          Tak  Używane   56 400
# 1                     Tak          Tak  Używane    3 500
# 2                     NaN          Tak  Używane   16 500
# 3                     NaN          Tak     Nowe  249 000
# 4                     NaN          Tak     Nowe  251 700
#
# [5 rows x 21 columns]

# %%
df.describe(include='all')
# Out:
#                                                      link Oferta od Kategoria  \
# count                                                1794      1794      1794
# unique                                               1790         2         1
# top     https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
# freq                                                    2       932      1794
# mean                                                  NaN       NaN       NaN
# std                                                   NaN       NaN       NaN
# min                                                   NaN       NaN       NaN
# 25%                                                   NaN       NaN       NaN
# 50%                                                   NaN       NaN       NaN
# 75%                                                   NaN       NaN       NaN
# max                                                   NaN       NaN       NaN
#
#               Generacja  Rok produkcji Przebieg Pojemność skokowa  \
# count              1769    1794.000000     1778              1781
# unique                8            NaN     1079                29
# top     VII (2012-2020)            NaN     1 km         1 598 cm3
# freq                835            NaN       45               437
# mean                NaN    2013.056299      NaN               NaN
# std                 NaN       6.617226      NaN               NaN
# min                 NaN    1977.000000      NaN               NaN
# 25%                 NaN    2009.000000      NaN               NaN
# 50%                 NaN    2014.000000      NaN               NaN
# 75%                 NaN    2018.000000      NaN               NaN
# max                 NaN    2023.000000      NaN               NaN
#
#        Rodzaj paliwa     Moc Skrzynia biegów  ... Spalanie W Mieście  \
# count           1794    1789            1791  ...               1105
# unique             6      49               2  ...                 54
# top          Benzyna  105 KM        Manualna  ...          6 l/100km
# freq            1001     287            1380  ...                223
# mean             NaN     NaN             NaN  ...                NaN
# std              NaN     NaN             NaN  ...                NaN
# min              NaN     NaN             NaN  ...                NaN
# 25%              NaN     NaN             NaN  ...                NaN
# 50%              NaN     NaN             NaN  ...                NaN
# 75%              NaN     NaN             NaN  ...                NaN
# max              NaN     NaN             NaN  ...                NaN
#
#        Typ nadwozia Liczba drzwi  Liczba miejsc   Kolor Kraj pochodzenia  \
# count          1794  1790.000000    1752.000000    1794             1438
# unique            8          NaN            NaN      17               15
# top         Kompakt          NaN            NaN  Czarny           Polska
# freq           1067          NaN            NaN     427              696
# mean            NaN     4.841341       4.990297     NaN              NaN
# std             NaN     0.558956       0.128327     NaN              NaN
# min             NaN     2.000000       2.000000     NaN              NaN
# 25%             NaN     5.000000       5.000000     NaN              NaN
# 50%             NaN     5.000000       5.000000     NaN              NaN
# 75%             NaN     5.000000       5.000000     NaN              NaN
# max             NaN     6.000000       5.000000     NaN              NaN
#
#        Zarejestrowany w Polsce Bezwypadkowy     Stan    Cena
# count                     1082         1794     1794    1794
# unique                       1            1        2     742
# top                        Tak          Tak  Używane  25 900
# freq                      1082         1794     1677      24
# mean                       NaN          NaN      NaN     NaN
# std                        NaN          NaN      NaN     NaN
# min                        NaN          NaN      NaN     NaN
# 25%                        NaN          NaN      NaN     NaN
# 50%                        NaN          NaN      NaN     NaN
# 75%                        NaN          NaN      NaN     NaN
# max                        NaN          NaN      NaN     NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# 1. The column 'links' has to be checked for duplicates
# 2. Columns that provide little use for analysis will have to be dropped
# 3. Numeric values need to be converted to numeric
# 4. NaN values need to be filled with appropriate values

# %%
#First we investigate the duplicated links
df_links = pd.DataFrame(df['link'].value_counts()).reset_index()
duplicate_links = df_links['index'][df_links['link']==2].tolist()
#identical duplicates
df[df['link'].isin(duplicate_links)]
# Out:
#                                                    link        Oferta od  \
# 383   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 384   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 543   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 544   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 767   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 768   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1087  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1088  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
#
#      Kategoria        Generacja  Rok produkcji    Przebieg Pojemność skokowa  \
# 383    Osobowe  VII (2012-2020)           2015  111 300 km         1 395 cm3
# 384    Osobowe  VII (2012-2020)           2015  111 300 km         1 395 cm3
# 543    Osobowe  VII (2012-2020)           2017  111 600 km         1 400 cm3
# 544    Osobowe  VII (2012-2020)           2017  111 600 km         1 400 cm3
# 767    Osobowe  VII (2012-2020)           2019   67 300 km         1 598 cm3
# 768    Osobowe  VII (2012-2020)           2019   67 300 km         1 598 cm3
# 1087   Osobowe   IV (1997-2006)           1999   98 000 km         1 390 cm3
# 1088   Osobowe   IV (1997-2006)           1999   98 000 km         1 390 cm3
#
#      Rodzaj paliwa     Moc Skrzynia biegów  ... Spalanie W Mieście  \
# 383        Benzyna  122 KM    Automatyczna  ...          6 l/100km
# 384        Benzyna  122 KM    Automatyczna  ...          6 l/100km
# 543        Benzyna  125 KM        Manualna  ...                NaN
# 544        Benzyna  125 KM        Manualna  ...                NaN
# 767         Diesel  116 KM        Manualna  ...                NaN
# 768         Diesel  116 KM        Manualna  ...                NaN
# 1087       Benzyna   75 KM        Manualna  ...          8 l/100km
# 1088       Benzyna   75 KM        Manualna  ...          8 l/100km
#
#        Typ nadwozia Liczba drzwi  Liczba miejsc     Kolor Kraj pochodzenia  \
# 383         Kompakt          5.0            5.0    Czarny           Polska
# 384         Kompakt          5.0            5.0    Czarny           Polska
# 543         Kompakt          5.0            5.0    Czarny           Polska
# 544         Kompakt          5.0            5.0    Czarny           Polska
# 767           Kombi          5.0            5.0     Biały           Polska
# 768           Kombi          5.0            5.0     Biały           Polska
# 1087  Auta miejskie          3.0            5.0  Czerwony           Niemcy
# 1088  Auta miejskie          3.0            5.0  Czerwony           Niemcy
#
#      Zarejestrowany w Polsce Bezwypadkowy     Stan    Cena
# 383                      NaN          Tak  Używane  60 885
# 384                      NaN          Tak  Używane  60 885
# 543                      Tak          Tak  Używane  67 600
# 544                      Tak          Tak  Używane  67 600
# 767                      Tak          Tak  Używane  84 900
# 768                      Tak          Tak  Używane  84 900
# 1087                     NaN          Tak  Używane   2 850
# 1088                     NaN          Tak  Używane   2 850
#
# [8 rows x 21 columns]

# %%
#Those look like regular duplicates so let's get rid of them
df.drop_duplicates(subset=['link'], inplace=True)
#check
df[df['link'].isin(duplicate_links)]
# Out:
#                                                    link        Oferta od  \
# 383   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 543   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 767   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1087  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
#
#      Kategoria        Generacja  Rok produkcji    Przebieg Pojemność skokowa  \
# 383    Osobowe  VII (2012-2020)           2015  111 300 km         1 395 cm3
# 543    Osobowe  VII (2012-2020)           2017  111 600 km         1 400 cm3
# 767    Osobowe  VII (2012-2020)           2019   67 300 km         1 598 cm3
# 1087   Osobowe   IV (1997-2006)           1999   98 000 km         1 390 cm3
#
#      Rodzaj paliwa     Moc Skrzynia biegów  ... Spalanie W Mieście  \
# 383        Benzyna  122 KM    Automatyczna  ...          6 l/100km
# 543        Benzyna  125 KM        Manualna  ...                NaN
# 767         Diesel  116 KM        Manualna  ...                NaN
# 1087       Benzyna   75 KM        Manualna  ...          8 l/100km
#
#        Typ nadwozia Liczba drzwi  Liczba miejsc     Kolor Kraj pochodzenia  \
# 383         Kompakt          5.0            5.0    Czarny           Polska
# 543         Kompakt          5.0            5.0    Czarny           Polska
# 767           Kombi          5.0            5.0     Biały           Polska
# 1087  Auta miejskie          3.0            5.0  Czerwony           Niemcy
#
#      Zarejestrowany w Polsce Bezwypadkowy     Stan    Cena
# 383                      NaN          Tak  Używane  60 885
# 543                      Tak          Tak  Używane  67 600
# 767                      Tak          Tak  Używane  84 900
# 1087                     NaN          Tak  Używane   2 850
#
# [4 rows x 21 columns]

# %%
#Next let's convert numeric data to int
#cena
df['Cena'] = df['Cena'].str.replace(' ', '')
df['Cena'] = df['Cena'].astype('int64')
df['Cena'].describe()
# Out:
# count      1790.000000
# mean      55505.897207
# std       46659.580120
# min        2300.000000
# 25%       22100.000000
# 50%       45900.000000
# 75%       69900.000000
# max      280080.000000
# Name: Cena, dtype: float64

# %%
df['Przebieg'] = df['Przebieg'].str.replace(' km', '')
df['Przebieg'] = df['Przebieg'].str.replace(' ', '')

# %%
#investigate NaN values
df[['Rok produkcji']][df['Przebieg'].isna()].value_counts()
# Out:
# Rok produkcji
# 2023             12
# 2022              4
# dtype: int64

# %%
#all of those cars are brand new so let's set the values to 0 and cast as numeric
df['Przebieg'] = pd.to_numeric(df['Przebieg'].fillna(0))
#df['Przebieg'] = pd.to_numeric(df['Przebieg'])
df['Przebieg'].describe()
# Out:
# count      1790.000000
# mean     157260.482123
# std       83671.298916
# min           0.000000
# 25%      100594.000000
# 50%      167415.000000
# 75%      212754.500000
# max      435000.000000
# Name: Przebieg, dtype: float64

# %%
#Pojemność skokowa - same treatment
df['Pojemność skokowa'] = df['Pojemność skokowa'].str.replace(' cm3', '')
df['Pojemność skokowa'] = df['Pojemność skokowa'].str.replace(' ', '')
df['Pojemność skokowa'] = pd.to_numeric(df['Pojemność skokowa'])

# %%
#checking NaNs
df[df['Pojemność skokowa'].isna()]
#NaNs for electric cars
# Out:
#                                                    link        Oferta od  \
# 151   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 177   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 185   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 318   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 458   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 460   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 694   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 913   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 917   https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 975   https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 1378  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1628  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1727  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
#
#      Kategoria        Generacja  Rok produkcji  Przebieg  Pojemność skokowa  \
# 151    Osobowe  VII (2012-2020)           2019     22000                NaN
# 177    Osobowe  VII (2012-2020)           2019     42000                NaN
# 185    Osobowe  VII (2012-2020)           2017    161627                NaN
# 318    Osobowe  VII (2012-2020)           2016     70000                NaN
# 458    Osobowe  VII (2012-2020)           2019     47301                NaN
# 460    Osobowe  VII (2012-2020)           2020     60851                NaN
# 694    Osobowe  VII (2012-2020)           2018     64000                NaN
# 913    Osobowe  VII (2012-2020)           2015     71500                NaN
# 917    Osobowe  VII (2012-2020)           2015     77000                NaN
# 975    Osobowe  VII (2012-2020)           2018     72000                NaN
# 1378   Osobowe  VII (2012-2020)           2015    136000                NaN
# 1628   Osobowe  VII (2012-2020)           2019     45470                NaN
# 1727   Osobowe  VII (2012-2020)           2014    164324                NaN
#
#      Rodzaj paliwa     Moc Skrzynia biegów  ... Spalanie W Mieście  \
# 151    Elektryczny  136 KM    Automatyczna  ...                NaN
# 177    Elektryczny  136 KM    Automatyczna  ...                NaN
# 185    Elektryczny  136 KM    Automatyczna  ...                NaN
# 318    Elektryczny  115 KM    Automatyczna  ...                NaN
# 458    Elektryczny  136 KM             NaN  ...                NaN
# 460    Elektryczny  136 KM             NaN  ...                NaN
# 694    Elektryczny  136 KM    Automatyczna  ...                NaN
# 913    Elektryczny  115 KM    Automatyczna  ...                NaN
# 917    Elektryczny  115 KM    Automatyczna  ...                NaN
# 975    Elektryczny  136 KM    Automatyczna  ...                NaN
# 1378   Elektryczny  115 KM    Automatyczna  ...                NaN
# 1628   Elektryczny  136 KM    Automatyczna  ...                NaN
# 1727   Elektryczny  115 KM    Automatyczna  ...                NaN
#
#      Typ nadwozia Liczba drzwi  Liczba miejsc    Kolor Kraj pochodzenia  \
# 151       Kompakt          5.0            5.0    Biały           Niemcy
# 177       Kompakt          5.0            5.0  Srebrny           Polska
# 185       Kompakt          5.0            5.0    Biały              NaN
# 318       Kompakt          5.0            5.0   Czarny         Norwegia
# 458       Kompakt          5.0            5.0    Biały              NaN
# 460       Kompakt          5.0            5.0    Szary              NaN
# 694       Kompakt          5.0            5.0   Beżowy         Norwegia
# 913       Kompakt          5.0            5.0    Biały              NaN
# 917       Kompakt          5.0            5.0   Czarny              NaN
# 975       Kompakt          5.0            NaN   Czarny         Norwegia
# 1378      Kompakt          5.0            5.0   Czarny              NaN
# 1628      Kompakt          5.0            5.0    Biały           Polska
# 1727      Kompakt          5.0            5.0    Biały         Norwegia
#
#      Zarejestrowany w Polsce Bezwypadkowy     Stan    Cena
# 151                      Tak          Tak  Używane  125999
# 177                      NaN          Tak  Używane  119999
# 185                      Tak          Tak  Używane   97170
# 318                      Tak          Tak  Używane   85900
# 458                      Tak          Tak  Używane  117000
# 460                      Tak          Tak  Używane  115000
# 694                      NaN          Tak  Używane   99000
# 913                      Tak          Tak  Używane   84900
# 917                      NaN          Tak  Używane   70900
# 975                      NaN          Tak  Używane  109000
# 1378                     NaN          Tak  Używane   73798
# 1628                     Tak          Tak  Używane  121770
# 1727                     NaN          Tak  Używane   60000
#
# [13 rows x 21 columns]

# %%
#Checking counts of fuel type
df['Rodzaj paliwa'].value_counts()
# Out:
# Benzyna        998
# Diesel         758
# Benzyna+LPG     16
# Elektryczny     13
# Hybryda          4
# Benzyna+CNG      1
# Name: Rodzaj paliwa, dtype: int64

# %%
#because there are very few examples of fuel types other than Diesel and Benzyna we drop them
df.drop(df[~(df['Rodzaj paliwa'].isin(['Benzyna', 'Diesel']))].index, inplace=True)
df['Rodzaj paliwa'].value_counts()
# Out:
# Benzyna    998
# Diesel     758
# Name: Rodzaj paliwa, dtype: int64

# %%
#Repeat for Moc
df['Moc'] = df['Moc'].str.replace(' KM', '')
df['Moc'] = pd.to_numeric(df['Moc'])
df[df['Moc'].isna()]
# Out:
#                                                    link Oferta od Kategoria  \
# 3     https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
# 4     https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
# 25    https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
# 1585  https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
# 1586  https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
#
#          Generacja  Rok produkcji  Przebieg  Pojemność skokowa Rodzaj paliwa  \
# 3     VIII (2020-)           2022         0             1984.0       Benzyna
# 4     VIII (2020-)           2022         0             1984.0       Benzyna
# 25    VIII (2020-)           2022         0             1984.0       Benzyna
# 1585           NaN           2005    190000             1896.0        Diesel
# 1586           NaN           2009    168000             1998.0        Diesel
#
#       Moc Skrzynia biegów  ... Spalanie W Mieście Typ nadwozia Liczba drzwi  \
# 3     NaN    Automatyczna  ...                NaN      Kompakt          NaN
# 4     NaN    Automatyczna  ...                NaN      Kompakt          NaN
# 25    NaN    Automatyczna  ...                NaN      Kompakt          NaN
# 1585  NaN        Manualna  ...                NaN      Kompakt          5.0
# 1586  NaN        Manualna  ...                NaN      Kompakt          5.0
#
#       Liczba miejsc      Kolor Kraj pochodzenia Zarejestrowany w Polsce  \
# 3               NaN      Biały           Polska                     NaN
# 4               NaN     Czarny           Polska                     NaN
# 25              NaN  Niebieski           Polska                     NaN
# 1585            5.0    Srebrny           Belgia                     NaN
# 1586            5.0    Srebrny           Belgia                     NaN
#
#      Bezwypadkowy     Stan    Cena
# 3             Tak     Nowe  249000
# 4             Tak     Nowe  251700
# 25            Tak     Nowe  250380
# 1585          Tak  Używane   22500
# 1586          Tak  Używane   34900
#
# [5 rows x 21 columns]

# %%
df['Moc'] = df['Moc'].fillna(df.groupby(['Rok produkcji', 'Pojemność skokowa', 'Rodzaj paliwa'])['Moc'].transform('mean'))
#still one more to fill, we'll use overall mean
df[df['Moc'].isna()]
# Out:
#                                                    link Oferta od Kategoria  \
# 1586  https://www.otomoto.pl/oferta/volkswagen-golf-...     Firmy   Osobowe
#
#      Generacja  Rok produkcji  Przebieg  Pojemność skokowa Rodzaj paliwa  Moc  \
# 1586       NaN           2009    168000             1998.0        Diesel  NaN
#
#      Skrzynia biegów  ... Spalanie W Mieście Typ nadwozia Liczba drzwi  \
# 1586        Manualna  ...                NaN      Kompakt          5.0
#
#       Liczba miejsc    Kolor Kraj pochodzenia Zarejestrowany w Polsce  \
# 1586            5.0  Srebrny           Belgia                     NaN
#
#      Bezwypadkowy     Stan   Cena
# 1586          Tak  Używane  34900
#
# [1 rows x 21 columns]

# %%
df['Moc'] = df['Moc'].fillna(df['Moc'].mean())
#finally it's empty
df[df['Moc'].isna()]
# Out:
# Empty DataFrame
# Columns: [link, Oferta od, Kategoria, Generacja, Rok produkcji, Przebieg, Pojemność skokowa, Rodzaj paliwa, Moc, Skrzynia biegów, Napęd, Spalanie W Mieście, Typ nadwozia, Liczba drzwi, Liczba miejsc, Kolor, Kraj pochodzenia, Zarejestrowany w Polsce, Bezwypadkowy, Stan, Cena]
# Index: []
#
# [0 rows x 21 columns]

# %%
#verifying if the mean was calculated correctly
print(df['Moc'].loc[(df['Rok produkcji']==2022) & (df['Pojemność skokowa']==1984) & df['Moc'].notnull() & (df['Rodzaj paliwa']=='Benzyna')].mean())
print(df['Moc'].loc[25])
# Out:
# 304.9
# 304.9

# %%
#too few examples of drives other than front wheels
df['Napęd'].value_counts()
# Out:
# Na przednie koła                 1472
# 4x4 (dołączany automatycznie)      58
# 4x4 (stały)                        18
# 4x4 (dołączany ręcznie)             8
# Na tylne koła                       5
# Name: Napęd, dtype: int64

# %%
df.drop(df[~(df['Napęd'].isin(['Na przednie koła']))].index, inplace=True)
df['Napęd'].value_counts()
# Out:
# Na przednie koła    1472
# Name: Napęd, dtype: int64

# %%
df[df['Spalanie W Mieście'].isna()]
# Out:
#                                                    link        Oferta od  \
# 21    https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 28    https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 29    https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 30    https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 32    https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# ...                                                 ...              ...
# 1758  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 1760  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1763  https://www.otomoto.pl/oferta/volkswagen-golf-...  Osoby prywatnej
# 1772  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
# 1788  https://www.otomoto.pl/oferta/volkswagen-golf-...            Firmy
#
#      Kategoria        Generacja  Rok produkcji  Przebieg  Pojemność skokowa  \
# 21     Osobowe     VIII (2020-)           2023         8             1498.0
# 28     Osobowe  VII (2012-2020)           2014    189736             1598.0
# 29     Osobowe  VII (2012-2020)           2019     74674             1984.0
# 30     Osobowe     VIII (2020-)           2023         5             1984.0
# 32     Osobowe  VII (2012-2020)           2018     49494             1498.0
# ...        ...              ...            ...       ...                ...
# 1758   Osobowe              NaN           2018     50000              999.0
# 1760   Osobowe  VII (2012-2020)           2018    181950             1598.0
# 1763   Osobowe  VII (2012-2020)           2016    144000             1600.0
# 1772   Osobowe     VIII (2020-)           2020     44216             1498.0
# 1788   Osobowe   II (1983-1992)           1988    142961             1781.0
#
#      Rodzaj paliwa    Moc Skrzynia biegów             Napęd  \
# 21         Benzyna  150.0    Automatyczna  Na przednie koła
# 28          Diesel  105.0        Manualna  Na przednie koła
# 29         Benzyna  245.0    Automatyczna  Na przednie koła
# 30         Benzyna  245.0    Automatyczna  Na przednie koła
# 32         Benzyna  150.0    Automatyczna  Na przednie koła
# ...            ...    ...             ...               ...
# 1758       Benzyna  110.0        Manualna  Na przednie koła
# 1760        Diesel  115.0        Manualna  Na przednie koła
# 1763        Diesel  110.0        Manualna  Na przednie koła
# 1772       Benzyna  130.0        Manualna  Na przednie koła
# 1788       Benzyna  107.0        Manualna  Na przednie koła
#
#      Spalanie W Mieście Typ nadwozia  Liczba drzwi  Liczba miejsc      Kolor  \
# 21                  NaN      Kompakt           5.0            5.0      Żółty
# 28                  NaN        Kombi           5.0            5.0    Srebrny
# 29                  NaN      Kompakt           5.0            5.0      Biały
# 30                  NaN      Kompakt           5.0            5.0      Biały
# 32                  NaN        Kombi           5.0            5.0     Czarny
# ...                 ...          ...           ...            ...        ...
# 1758                NaN        Kombi           5.0            NaN      Szary
# 1760                NaN        Kombi           5.0            5.0    Srebrny
# 1763                NaN        Kombi           5.0            5.0    Srebrny
# 1772                NaN      Kompakt           5.0            5.0      Szary
# 1788                NaN      Kompakt           5.0            5.0  Niebieski
#
#      Kraj pochodzenia Zarejestrowany w Polsce Bezwypadkowy     Stan    Cena
# 21             Polska                     NaN          Tak     Nowe  169900
# 28             Niemcy                     Tak          Tak  Używane   39999
# 29             Polska                     Tak          Tak  Używane  114900
# 30             Polska                     NaN          Tak     Nowe  190900
# 32             Polska                     Tak          Tak  Używane   99900
# ...               ...                     ...          ...      ...     ...
# 1758           Polska                     Tak          Tak  Używane   56900
# 1760           Polska                     Tak          Tak  Używane   47900
# 1763           Niemcy                     Tak          Tak  Używane   56900
# 1772           Polska                     Tak          Tak  Używane  105900
# 1788              NaN                     NaN          Tak  Używane   49999
#
# [586 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['link', 'Oferta od', 'Kategoria', 'Generacja', 'Rok produkcji',
#        'Przebieg', 'Pojemność skokowa', 'Rodzaj paliwa', 'Moc',
#        'Skrzynia biegów', 'Napęd', 'Spalanie W Mieście', 'Typ nadwozia',
#        'Liczba drzwi', 'Liczba miejsc', 'Kolor', 'Kraj pochodzenia',
#        'Zarejestrowany w Polsce', 'Bezwypadkowy', 'Stan', 'Cena'],
#       dtype='object')

# %%
#get rid of columns we don't need for analysis
df.drop(columns=['link', 'Kategoria', 'Generacja', 'Liczba drzwi', 'Liczba miejsc', 'Typ nadwozia', 'Kolor', 'Bezwypadkowy', 'Stan'], inplace=True)
